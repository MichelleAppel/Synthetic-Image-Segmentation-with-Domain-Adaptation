# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

import matplotlib.pyplot as plt

# %%
from unity import UnityDataset, UnityDataModule

# %%
unitydataset = UnityDataset(epoch_length=100, port=8093)

# %%
unitydatamodule = UnityDataModule(unitydataset, batch_size=5, num_workers=0)

# %%
for rgb, outline in unitydatamodule.train_dataloader():
    print(rgb.shape, outline.shape)
    break
    # plt.imshow(rgb[0].permute(1, 2, 0))
    # plt.show()
    # plt.imshow(outline[0].permute(1, 2, 0))
    # plt.show()
# Out:
# 510331
# EOI received
# 35320
# EOI received
# EOT received
# 511070
# EOI received
# 35320
# EOI received
# EOT received
# 511778
# EOI received
# 35320
# EOI received
# EOT received
# 511237
# EOI received
# 35320
# EOI received
# EOT received
# 511796
# EOI received
# 35320
# EOI received
# EOT received
# torch.Size([5, 3, 480, 640]) torch.Size([5, 3, 480, 640])

# %%
plt.imshow(rgb[0].permute(1, 2, 0))

# %%
plt.imshow(outline[0].permute(1, 2, 0))

# %%
# # test BDSD500 dataset

# bdsd500 = BDSD500(data_root=r'C:\Users\appel\Documents\Project\synthetic-image-segmentation\data\real\bdsd500')
# bdsd500.setup()
# train_loader = bdsd500.train_dataloader()

# for batch in train_loader:
#     print(len(batch))
#     plt.imshow(batch[0][0].permute(1, 2, 0))
#     plt.show()

#     plt.imshow(batch[1][0].permute(1, 2, 0))
#     plt.show()
#     break

# %%
# # test NYUDv2 dataset

# nyudv2 = NYUDv2(data_root=r'C:\Users\appel\Documents\Project\synthetic-image-segmentation\data\real\nyudv2')
# nyudv2.setup()
# train_loader = nyudv2.train_dataloader()

# for batch in train_loader:
#     print(batch[0].shape, batch[1].shape)

#     plt.imshow(batch[0][0].permute(1, 2, 0))
#     plt.show()

#     plt.imshow(batch[1][0].permute(1, 2, 0))
#     plt.show()
#     break
